# %% [markdown]
# ## Part 2
#
# > _Exercises_: Chapter 5 (just some questions from the text)
# >
# > * _Mean and median_: Explain the difference between the mean and the median in your own words. In what kinds of dataset are the mean and median similar? Can you think of a dataset where the mean and median would be very different?
# >  _mean is the average value, median is the value in the middle of the distribution._
# > _In a normal distribution, the mean and median are similar or the same_
# > _In a negative/positive scew the median and mean are different_
# > * _Variance_: Explain the variance in your own words.
# > _Its a number that teels you how much the datapoint vary from the mean_
# > * _A paradox_: What is Simpson's Paradox. Provide your own example of a dataset where this issue occurs.
# > ![image.png](attachment:image.png)
# > * _Correlation and causation_: Explain what's funny about [**this comic**](https://xkcd.com/552/).

# %%
from urllib.request import urlretrieve

url1 = ("https://raw.githubusercontent.com/suneman/socialdataanalysis2017/master/files/data1.tsv")
filename1 = "data1.tsv"
urlretrieve(url1, filename1)
url2 = ("https://raw.githubusercontent.com/suneman/socialdataanalysis2017/master/files/data2.tsv")
filename2 = "data2.tsv"
urlretrieve(url2, filename2)
url3 = ("https://raw.githubusercontent.com/suneman/socialdataanalysis2017/master/files/data3.tsv")
filename3 = "data3.tsv"
urlretrieve(url3, filename3)
url4 = ("https://raw.githubusercontent.com/suneman/socialdataanalysis2017/master/files/data4.tsv")
filename4 = "data4.tsv"
urlretrieve(url4, filename4)


import numpy as np
import csv

with open("data1.tsv") as f:
    data = (line.strip().split('\t') for line in f)
    for row in data:
        print(row)
# Out:
# ['10', '8.04']
# ['8', '6.95']
# ['13', '7.58']
# ['9', '8.81']
# ['11', '8.33']
# ['14', '9.96']
# ['6', '7.24']
# ['4', '4.26']
# ['12', '10.84']
# ['7', '4.82']
# ['5', '5.68']
